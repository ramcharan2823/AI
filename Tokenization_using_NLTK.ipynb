# %% [markdown]
# <a href="https://colab.research.google.com/github/ramcharan2823/AI/blob/NLP_ML/Tokenization_using_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.9.1

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

text = "Hello, welcome to NLTK!"
tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Hello', ',', 'welcome', 'to', 'NLTK', '!']

# %%
corpus = """Hello welcome to Ramcharan's NLP learning.
Please do learn properly entire course ! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello welcome to Ramcharan's NLP learning.
# Please do learn properly entire course ! to become expert in NLP.

# %%
## Tokenization
## Sentence ----> Paragraph
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
# Hello welcome to Ramcharan's NLP learning.
# Please do learn properly entire course !
# to become expert in NLP.

# %%
## Tokenization
## Paragraph ---> Words
## sentence ---> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'Ramcharan',
#  "'s",
#  'NLP',
#  'learning',
#  '.',
#  'Please',
#  'do',
#  'learn',
#  'properly',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', 'to', 'Ramcharan', "'s", 'NLP', 'learning', '.']
# ['Please', 'do', 'learn', 'properly', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'Ramcharan',
#  "'",
#  's',
#  'NLP',
#  'learning',
#  '.',
#  'Please',
#  'do',
#  'learn',
#  'properly',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'Ramcharan',
#  "'s",
#  'NLP',
#  'learning.',
#  'Please',
#  'do',
#  'learn',
#  'properly',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
